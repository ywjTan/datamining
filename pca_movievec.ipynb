# %%
import numpy as np
from sklearn.decomposition import PCA
# Out:
# C:\Users\60139\miniconda3\lib\site-packages\sklearn\utils\deprecation.py:143: FutureWarning: The sklearn.decomposition.pca module is  deprecated in version 0.22 and will be removed in version 0.24. The corresponding classes / functions should instead be imported from sklearn.decomposition. Anything that cannot be imported from sklearn.decomposition is now part of the private API.
#   warnings.warn(message, FutureWarning)

# %%
movievec = pd.read_csv('./data/movie_vec.csv')

# %%
movie_dict={}
for i in range(movievec.shape[0]):
    movie_dict[movievec['movieId'][i]]=list(map(float,movievec['movieVec'][i].strip('[').strip(']').split(',')))

# %%
veclist=[]
for id in movie_dict.keys():
     veclist.append(movie_dict[id])

# %%
x=np.array(veclist)

# %%
print(x.shape)
# Out:
# (27278, 128)

# %%
pca = PCA(n_components=2)
reduced_data_pca = pca.fit_transform(x)
print(pca.explained_variance_ratio_)
# Out:
# [0.14576029 0.10579092]

# %%
import matplotlib.pyplot as plt
fig, ax = plt.subplots()
for i in range(int(reduced_data_pca.size/2)):
    team = reduced_data_pca[i]
    ax.scatter(team[0], team[1])
    #ax.annotate(team_name[i], (team[0], team[1]))
plt.savefig("movie_vec_pca.png")
plt.show()
